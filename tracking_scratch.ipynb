# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import hvplot.pandas
import holoviews as hv

# %%
matchups_df = pd.read_csv('data/nfl-big-data-bowl-2024/matchups.csv')
matchups_df.head()
# Out:
#    matchup      gameId  week home away
# 0   LA_BUF  2022090800     1   LA  BUF
# 1   ATL_NO  2022091100     1  ATL   NO
# 2  CAR_CLE  2022091101     1  CAR  CLE
# 3   CHI_SF  2022091102     1  CHI   SF
# 4  CIN_PIT  2022091103     1  CIN  PIT

# %%
players_basic_df = pd.read_csv('data/nfl-big-data-bowl-2024/players_basic.csv')
players_basic_df.head()
# Out:
#   position     displayName
# 0       QB       Tom Brady
# 1        T    Jason Peters
# 2       QB   Aaron Rodgers
# 3       TE  Marcedes Lewis
# 4       QB       Matt Ryan

# %%
positions_all = players_basic_df['position'].unique()
print(positions_all)
# Out:
# ['QB' 'T' 'TE' 'WR' 'DE' 'NT' 'SS' 'FS' 'G' 'OLB' 'DT' 'CB' 'RB' 'C' 'ILB'
#  'MLB' 'FB' 'LS' 'DB']

# %%
positions_off = ['QB','T','TE','WR','G','FB','RB','C']
positions_def = ['DE','NT','SS','FS','OLB','DT','CB','ILB','MLB','DB']

# %%
tracking_df = pd.read_csv('data/nfl-big-data-bowl-2024/tracking_week_2.csv')
tracking_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022091500      55  40011.0  Travis Kelce        1
# 1  2022091500      55  40011.0  Travis Kelce        2
# 2  2022091500      55  40011.0  Travis Kelce        3
# 3  2022091500      55  40011.0  Travis Kelce        4
# 4  2022091500      55  40011.0  Travis Kelce        5
#
#                          time  jerseyNumber club playDirection     x     y  \
# 0  2022-09-15 20:16:32.700000          87.0   KC          left  87.2  24.9
# 1  2022-09-15 20:16:32.799999          87.0   KC          left  87.2  24.9
# 2  2022-09-15 20:16:32.900000          87.0   KC          left  87.2  24.9
# 3  2022-09-15 20:16:33.000000          87.0   KC          left  87.2  24.9
# 4  2022-09-15 20:16:33.099999          87.0   KC          left  87.2  24.9
#
#       s     a  dis       o     dir event
# 0  0.00  0.00  0.0  263.11  138.55   NaN
# 1  0.00  0.00  0.0  263.11  142.54   NaN
# 2  0.00  0.00  0.0  262.47  143.82   NaN
# 3  0.00  0.00  0.0  262.47  149.71   NaN
# 4  0.01  0.15  0.0  262.47  309.38   NaN

# %%
tracking_df = pd.merge(players_basic_df, tracking_df, how='left', left_on='displayName', right_on='displayName')

# %%
def clean_data(tracking_df):
    # Replace missing values with 0 in columns: 'jerseyNumber', 'nflId'
    tracking_df = tracking_df.fillna({'jerseyNumber': 0, 'nflId': 0})
    # Change column type to string for column: 'nflId'
    tracking_df = tracking_df.astype({'nflId': 'string'})
    # Replace all instances of ".0" with "" in column: 'nflId'
    tracking_df['nflId'] = tracking_df['nflId'].str.replace(".0", "", case=False, regex=False)
    # Change column type to string for column: 'jerseyNumber'
    tracking_df = tracking_df.astype({'jerseyNumber': 'string'})
    # Replace all instances of ".0" with "" in column: 'jerseyNumber'
    tracking_df['jerseyNumber'] = tracking_df['jerseyNumber'].str.replace(".0", "", case=False, regex=False)
    # Change column type to string for columns: 'club', 'playDirection', 'event', 'displayName', 'time'
    tracking_df = tracking_df.astype({'club': 'string', 'playDirection': 'string','event': 'string','displayName': 'string','gameId': 'string',})
    # Reduce the floats to two decimal points
    tracking_df[['x', 'y', 's', 'a', 'dis']] = tracking_df[['x', 'y', 's', 'a', 'dis']].round(2)
    # Change column type to datetime64[ns] for column: 'time'
    tracking_df = tracking_df.astype({'time': 'datetime64[ns]'})
    return tracking_df

tracking_df_clean = clean_data(tracking_df.copy())
tracking_df_clean.head()
# Out:
#   position displayName        gameId  playId  nflId  frameId  \
# 0       QB   Tom Brady  2022091804.0   378.0  25511      1.0
# 1       QB   Tom Brady  2022091804.0   378.0  25511      2.0
# 2       QB   Tom Brady  2022091804.0   378.0  25511      3.0
# 3       QB   Tom Brady  2022091804.0   378.0  25511      4.0
# 4       QB   Tom Brady  2022091804.0   378.0  25511      5.0
#
#                         time jerseyNumber club playDirection      x      y  \
# 0 2022-09-18 13:13:57.900000           12   TB         right  33.26  27.10
# 1 2022-09-18 13:13:58.000000           12   TB         right  33.27  27.10
# 2 2022-09-18 13:13:58.099999           12   TB         right  33.27  27.09
# 3 2022-09-18 13:13:58.200000           12   TB         right  33.26  27.09
# 4 2022-09-18 13:13:58.299999           12   TB         right  33.26  27.09
#
#      s    a  dis      o    dir event
# 0  0.0  0.0  0.0  93.07  77.36  <NA>
# 1  0.0  0.0  0.0  92.08  78.20  <NA>
# 2  0.0  0.0  0.0  91.37  79.00  <NA>
# 3  0.0  0.0  0.0  91.37  80.26  <NA>
# 4  0.0  0.0  0.0  91.37  82.45  <NA>

# %%
tracking_df_clean=pd.merge(tracking_df_clean, players_basic_df, how='left', left_on='displayName', right_on='displayName')
tracking_df_clean.head()
# Out:
#   position_x displayName        gameId  playId  nflId  frameId  \
# 0         QB   Tom Brady  2022091804.0   378.0  25511      1.0
# 1         QB   Tom Brady  2022091804.0   378.0  25511      2.0
# 2         QB   Tom Brady  2022091804.0   378.0  25511      3.0
# 3         QB   Tom Brady  2022091804.0   378.0  25511      4.0
# 4         QB   Tom Brady  2022091804.0   378.0  25511      5.0
#
#                         time jerseyNumber club playDirection      x      y  \
# 0 2022-09-18 13:13:57.900000           12   TB         right  33.26  27.10
# 1 2022-09-18 13:13:58.000000           12   TB         right  33.27  27.10
# 2 2022-09-18 13:13:58.099999           12   TB         right  33.27  27.09
# 3 2022-09-18 13:13:58.200000           12   TB         right  33.26  27.09
# 4 2022-09-18 13:13:58.299999           12   TB         right  33.26  27.09
#
#      s    a  dis      o    dir event position_y
# 0  0.0  0.0  0.0  93.07  77.36  <NA>         QB
# 1  0.0  0.0  0.0  92.08  78.20  <NA>         QB
# 2  0.0  0.0  0.0  91.37  79.00  <NA>         QB
# 3  0.0  0.0  0.0  91.37  80.26  <NA>         QB
# 4  0.0  0.0  0.0  91.37  82.45  <NA>         QB

# %%
catalog_play = tracking_df_clean[['gameId', 'playId']].copy()
tracking_df_clean['playId'].value_counts()
# Out:
# 56.0      6527
# 550.0     4025
# 1515.0    3916
# 3127.0    3814
# 2685.0    3784
#           ...
# 1172.0     242
# 3066.0     242
# 176.0      242
# 2437.0     242
# 400.0      242
# Name: playId, Length: 1197, dtype: int64

# %%
def clean_data(tracking_df_clean):    # Filter rows based on column: 'event'
    #tracking_df_clean = tracking_df_clean[tracking_df_clean['frameId'] == 6]
    tracking_df_clean = tracking_df_clean.rename(columns={'position_x': 'position'})
    tracking_df_clean = tracking_df_clean[tracking_df_clean['event'] == "ball_snap"]
    tracking_df_clean = tracking_df_clean[tracking_df_clean['playId'] == 1515]
    tracking_df_clean = tracking_df_clean[tracking_df_clean['gameId'] == "2022091808.0"]
    return tracking_df_clean

single_frame_play = clean_data(tracking_df_clean.copy())
single_frame_play.head()
# Out:
#        position      displayName        gameId  playId  nflId  frameId  \
# 13038         T   Trent Williams  2022091808.0  1515.0  35443      6.0
# 22741        NT         Al Woods  2022091808.0  1515.0  35562      6.0
# 142749       QB  Jimmy Garoppolo  2022091808.0  1515.0  41291      6.0
# 218214       TE      Tyler Kroft  2022091808.0  1515.0  42428      6.0
# 245647       FS    Quandre Diggs  2022091808.0  1515.0  42543      6.0
#
#                              time jerseyNumber club playDirection      x  \
# 13038  2022-09-18 17:13:09.599999           71   SF         right  28.25
# 22741  2022-09-18 17:13:09.599999           99  SEA         right  30.48
# 142749 2022-09-18 17:13:09.599999           10   SF         right  28.11
# 218214 2022-09-18 17:13:09.599999           81   SF         right  27.90
# 245647 2022-09-18 17:13:09.599999            6  SEA         right  42.49
#
#             y     s     a   dis       o     dir      event position_y
# 13038   32.68  0.00  0.00  0.02   94.34  249.99  ball_snap          T
# 22741   28.72  0.25  1.77  0.02  256.01  197.26  ball_snap         NT
# 142749  29.71  0.47  1.32  0.05  107.66  246.12  ball_snap         QB
# 218214  34.12  0.09  0.65  0.02   87.65  147.89  ball_snap         TE
# 245647  26.30  0.35  0.38  0.03  265.25  107.62  ball_snap         FS

# %%
single_frame_play.hvplot.scatter(
    x="x",
    y="y",
    xlim=(0, 120),  # Specify the boundaries for the x-axis
    ylim=(0, 53.3),   # Specify the boundaries for the y-axis
    by="club",
    hover_cols=["displayName", "club", "position_x"]
)
# Out:
# :NdOverlay   [club]
#    :Scatter   [x]   (y,displayName,club)

# %%
def clean_data(tracking_df_clean):    # Filter rows based on column: 'event'
    #tracking_df_clean = tracking_df_clean[tracking_df_clean['frameId'] == 21]
    #tracking_df_clean = tracking_df_clean[tracking_df_clean['event'] == "ball_snap"]
    tracking_df_clean = tracking_df_clean[tracking_df_clean['playId'] == 764]
    return tracking_df_clean

anime_frame_play = clean_data(tracking_df_clean.copy())
anime_frame_play.head()
# Out:
#     position_x displayName        gameId  playId  nflId  frameId  \
# 258         QB   Tom Brady  2022091804.0   764.0  25511      1.0
# 259         QB   Tom Brady  2022091804.0   764.0  25511      2.0
# 260         QB   Tom Brady  2022091804.0   764.0  25511      3.0
# 261         QB   Tom Brady  2022091804.0   764.0  25511      4.0
# 262         QB   Tom Brady  2022091804.0   764.0  25511      5.0
#
#                           time jerseyNumber club playDirection      x      y  \
# 258 2022-09-18 13:30:29.500000           12   TB         right  31.14  23.81
# 259 2022-09-18 13:30:29.599999           12   TB         right  31.14  23.82
# 260 2022-09-18 13:30:29.700000           12   TB         right  31.14  23.81
# 261 2022-09-18 13:30:29.799999           12   TB         right  31.14  23.81
# 262 2022-09-18 13:30:29.900000           12   TB         right  31.13  23.81
#
#        s    a  dis      o     dir event position_y
# 258  0.0  0.0  0.0  85.81   89.31  <NA>         QB
# 259  0.0  0.0  0.0  85.81   77.97  <NA>         QB
# 260  0.0  0.0  0.0  85.23   83.08  <NA>         QB
# 261  0.0  0.0  0.0  85.23   77.18  <NA>         QB
# 262  0.0  0.0  0.0  85.23  112.49  <NA>         QB
