# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
player_position_df = pd.read_csv('data/nfl-big-data-bowl-2024/players_basic.csv')
player_position_df.head()
# Out:
#   position     displayName
# 0       QB       Tom Brady
# 1        T    Jason Peters
# 2       QB   Aaron Rodgers
# 3       TE  Marcedes Lewis
# 4       QB       Matt Ryan

# %%
matchups_df = pd.read_csv('data/nfl-big-data-bowl-2024/matchups.csv')
matchups_df.head()
# Out:
#    matchup      gameId  week home away
# 0   LA_BUF  2022090800     1   LA  BUF
# 1   ATL_NO  2022091100     1  ATL   NO
# 2  CAR_CLE  2022091101     1  CAR  CLE
# 3   CHI_SF  2022091102     1  CHI   SF
# 4  CIN_PIT  2022091103     1  CIN  PIT

# %%
plays_df = pd.read_csv('data/nfl-big-data-bowl-2024/plays.csv')
plays_df.head()
# Out:
#        gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0  2022100908    3537          48723           Parker Hesse
# 1  2022091103    3126          52457         Chase Claypool
# 2  2022091111    1148          42547          Darren Waller
# 3  2022100212    2007          46461             Mike Boone
# 4  2022091900    1372          47857       Devin Singletary
#
#                                      playDescription  quarter  down  \
# 0  (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2  (8:57) D.Carr pass short middle to D.Waller to...        2     2
# 3  (13:12) M.Boone left tackle to DEN 44 for 7 ya...        3     2
# 4  (8:33) D.Singletary right guard to TEN 32 for ...        2     1
#
#    yardsToGo possessionTeam defensiveTeam  ... preSnapHomeTeamWinProbability  \
# 0         10            ATL            TB  ...                      0.976785
# 1         10            PIT           CIN  ...                      0.160485
# 2          5             LV           LAC  ...                      0.756661
# 3         10            DEN            LV  ...                      0.620552
# 4         10            BUF           TEN  ...                      0.836290
#
#    preSnapVisitorTeamWinProbability homeTeamWinProbabilityAdded  \
# 0                          0.023215                   -0.006110
# 1                          0.839515                   -0.010865
# 2                          0.243339                   -0.037409
# 3                          0.379448                   -0.002451
# 4                          0.163710                    0.001053
#
#    visitorTeamWinProbilityAdded  expectedPoints expectedPointsAdded  \
# 0                      0.006110        2.360609            0.981955
# 1                      0.010865        1.733344           -0.263424
# 2                      0.037409        1.312855            1.133666
# 3                      0.002451        1.641006           -0.043580
# 4                     -0.001053        3.686428           -0.167903
#
#    foulName1  foulName2  foulNFLId1  foulNFLId2
# 0        NaN        NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN
#
# [5 rows x 35 columns]

# %%
plays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12486 entries, 0 to 12485
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gameId                            12486 non-null  int64
#  1   playId                            12486 non-null  int64
#  2   ballCarrierId                     12486 non-null  int64
#  3   ballCarrierDisplayName            12486 non-null  object
#  4   playDescription                   12486 non-null  object
#  5   quarter                           12486 non-null  int64
#  6   down                              12486 non-null  int64
#  7   yardsToGo                         12486 non-null  int64
#  8   possessionTeam                    12486 non-null  object
#  9   defensiveTeam                     12486 non-null  object
#  10  yardlineSide                      12319 non-null  object
#  11  yardlineNumber                    12486 non-null  int64
#  12  gameClock                         12486 non-null  object
#  13  preSnapHomeScore                  12486 non-null  int64
#  14  preSnapVisitorScore               12486 non-null  int64
#  15  passResult                        6105 non-null   object
#  16  passLength                        5634 non-null   float64
#  17  penaltyYards                      615 non-null    float64
#  18  prePenaltyPlayResult              12486 non-null  int64
#  19  playResult                        12486 non-null  int64
#  20  playNullifiedByPenalty            12486 non-null  object
#  21  absoluteYardlineNumber            12486 non-null  int64
#  22  offenseFormation                  12482 non-null  object
#  23  defendersInTheBox                 12481 non-null  float64
#  24  passProbability                   12149 non-null  float64
#  25  preSnapHomeTeamWinProbability     12486 non-null  float64
#  26  preSnapVisitorTeamWinProbability  12486 non-null  float64
#  27  homeTeamWinProbabilityAdded       12486 non-null  float64
#  28  visitorTeamWinProbilityAdded      12486 non-null  float64
#  29  expectedPoints                    12486 non-null  float64
#  30  expectedPointsAdded               12485 non-null  float64
#  31  foulName1                         592 non-null    object
#  32  foulName2                         25 non-null     object
#  33  foulNFLId1                        592 non-null    float64
#  34  foulNFLId2                        25 non-null     float64
# dtypes: float64(12), int64(12), object(11)
# memory usage: 3.3+ MB

# %%
plays_df = pd.merge(player_position_df, plays_df, how='left', left_on='displayName', right_on='ballCarrierDisplayName')
plays_df.head()
# Out:
#   position   displayName        gameId  playId  ballCarrierId  \
# 0       QB     Tom Brady  2.022102e+09  2725.0        25511.0
# 1       QB     Tom Brady  2.022093e+09  2687.0        25511.0
# 2       QB     Tom Brady  2.022102e+09  3652.0        25511.0
# 3       QB     Tom Brady  2.022103e+09  3083.0        25511.0
# 4        T  Jason Peters           NaN     NaN            NaN
#
#   ballCarrierDisplayName                                    playDescription  \
# 0              Tom Brady  (:27) (No Huddle, Shotgun) T.Brady scrambles u...
# 1              Tom Brady  (1:08) (Shotgun) T.Brady scrambles up the midd...
# 2              Tom Brady  (7:07) T.Brady up the middle to PIT 29 for no ...
# 3              Tom Brady  (13:22) (Shotgun) T.Brady scrambles left end t...
# 4                    NaN                                                NaN
#
#    quarter  down  yardsToGo  ... preSnapHomeTeamWinProbability  \
# 0      3.0   2.0        8.0  ...                      0.766339
# 1      3.0   3.0        3.0  ...                      0.236263
# 2      4.0   3.0        1.0  ...                      0.738573
# 3      4.0   3.0       10.0  ...                      0.331841
# 4      NaN   NaN        NaN  ...                           NaN
#
#   preSnapVisitorTeamWinProbability homeTeamWinProbabilityAdded  \
# 0                         0.233661                    0.030954
# 1                         0.763737                   -0.052861
# 2                         0.261427                    0.027505
# 3                         0.668159                   -0.044003
# 4                              NaN                         NaN
#
#    visitorTeamWinProbilityAdded expectedPoints  expectedPointsAdded  \
# 0                     -0.030954       4.522505            -0.680631
# 1                      0.052861       0.354470            -1.556648
# 2                     -0.027505       3.937956            -1.125045
# 3                      0.044003       3.793404            -1.062754
# 4                           NaN            NaN                  NaN
#
#            foulName1 foulName2  foulNFLId1  foulNFLId2
# 0                NaN       NaN         NaN         NaN
# 1  Offensive Holding       NaN     53027.0         NaN
# 2                NaN       NaN         NaN         NaN
# 3                NaN       NaN         NaN         NaN
# 4                NaN       NaN         NaN         NaN
#
# [5 rows x 37 columns]

# %%
# Fill non-finite values with 0
plays_df['defendersInTheBox'] = plays_df['defendersInTheBox'].fillna(0)
plays_df['gameId'] = plays_df['gameId'].fillna(0)
# Convert the column to integer
plays_df['defendersInTheBox'] = plays_df['defendersInTheBox'].astype(int)
plays_df['gameId'] = plays_df['gameId'].astype(int)
# Change column type to string for columns: 'yardlineSide', 'possessionTeam', 'defensiveTeam'
plays_df = plays_df.astype({'yardlineSide': 'string', 'position':'string','possessionTeam': 'string', 'defensiveTeam': 'string','offenseFormation': 'string','ballCarrierId': 'string', 'ballCarrierDisplayName': 'string','passResult':'string','playNullifiedByPenalty':'string','playDescription':'string'})
# Change column type to datetime64[ns] for column: 'gameClock'
plays_df = plays_df.astype({'gameClock': 'datetime64[ns]',})
# Drop columns: 'passProbability', 'preSnapHomeTeamWinProbability' and 5 other columns
plays_df_clean = plays_df.drop(columns=['passProbability', 'preSnapHomeTeamWinProbability', 'preSnapVisitorTeamWinProbability', 'homeTeamWinProbabilityAdded', 'visitorTeamWinProbilityAdded', 'expectedPoints', 'expectedPointsAdded','foulName1', 'foulName2', 'foulNFLId1', 'foulNFLId2','prePenaltyPlayResult','penaltyYards','displayName'])
plays_df_clean.head()
# Out:
#   position      gameId  playId ballCarrierId ballCarrierDisplayName  \
# 0       QB  2022102301  2725.0       25511.0              Tom Brady
# 1       QB  2022092512  2687.0       25511.0              Tom Brady
# 2       QB  2022101607  3652.0       25511.0              Tom Brady
# 3       QB  2022102700  3083.0       25511.0              Tom Brady
# 4        T           0     NaN          <NA>                   <NA>
#
#                                      playDescription  quarter  down  \
# 0  (:27) (No Huddle, Shotgun) T.Brady scrambles u...      3.0   2.0
# 1  (1:08) (Shotgun) T.Brady scrambles up the midd...      3.0   3.0
# 2  (7:07) T.Brady up the middle to PIT 29 for no ...      4.0   3.0
# 3  (13:22) (Shotgun) T.Brady scrambles left end t...      4.0   3.0
# 4                                               <NA>      NaN   NaN
#
#    yardsToGo possessionTeam  ...           gameClock preSnapHomeScore  \
# 0        8.0             TB  ... 2024-03-17 00:27:00             14.0
# 1        3.0             TB  ... 2024-03-17 01:08:00              6.0
# 2        1.0             TB  ... 2024-03-17 07:07:00             20.0
# 3       10.0             TB  ... 2024-03-17 13:22:00             10.0
# 4        NaN           <NA>  ...                 NaT              NaN
#
#    preSnapVisitorScore passResult  passLength  playResult  \
# 0                  0.0          R         NaN         1.0
# 1                 14.0          R         NaN       -10.0
# 2                 12.0       <NA>         NaN         0.0
# 3                 17.0          R         NaN         1.0
# 4                  NaN       <NA>         NaN         NaN
#
#   playNullifiedByPenalty  absoluteYardlineNumber  offenseFormation  \
# 0                      N                    92.0           SHOTGUN
# 1                      Y                    80.0             EMPTY
# 2                      N                    81.0        SINGLEBACK
# 3                      N                    23.0           SHOTGUN
# 4                   <NA>                     NaN              <NA>
#
#   defendersInTheBox
# 0                 7
# 1                 5
# 2                 7
# 3                 5
# 4                 0
#
# [5 rows x 23 columns]

# %%
qb_plays = plays_df_clean[plays_df_clean['position'] == "QB"]
qb_plays.head()
# Out:
#        gameId  playId ballCarrierId ballCarrierDisplayName position  \
# 0  2022102301  2725.0       25511.0              Tom Brady       QB
# 1  2022092512  2687.0       25511.0              Tom Brady       QB
# 2  2022101607  3652.0       25511.0              Tom Brady       QB
# 3  2022102700  3083.0       25511.0              Tom Brady       QB
# 5  2022110603  3064.0       29851.0          Aaron Rodgers       QB
#
#                                      playDescription  quarter  down  \
# 0  (:27) (No Huddle, Shotgun) T.Brady scrambles u...      3.0   2.0
# 1  (1:08) (Shotgun) T.Brady scrambles up the midd...      3.0   3.0
# 2  (7:07) T.Brady up the middle to PIT 29 for no ...      4.0   3.0
# 3  (13:22) (Shotgun) T.Brady scrambles left end t...      4.0   3.0
# 5  (12:24) (Shotgun) A.Rodgers scrambles up the m...      4.0   3.0
#
#    yardsToGo possessionTeam  ...           gameClock preSnapHomeScore  \
# 0        8.0             TB  ... 2024-03-17 00:27:00             14.0
# 1        3.0             TB  ... 2024-03-17 01:08:00              6.0
# 2        1.0             TB  ... 2024-03-17 07:07:00             20.0
# 3       10.0             TB  ... 2024-03-17 13:22:00             10.0
# 5       17.0             GB  ... 2024-03-17 12:24:00             15.0
#
#    preSnapVisitorScore passResult  passLength  playResult  \
# 0                  0.0          R         NaN         1.0
# 1                 14.0          R         NaN       -10.0
# 2                 12.0       <NA>         NaN         0.0
# 3                 17.0          R         NaN         1.0
# 5                  6.0          R         NaN        18.0
#
#   playNullifiedByPenalty  absoluteYardlineNumber  offenseFormation  \
# 0                      N                    92.0           SHOTGUN
# 1                      Y                    80.0             EMPTY
# 2                      N                    81.0        SINGLEBACK
# 3                      N                    23.0           SHOTGUN
# 5                      N                    46.0           SHOTGUN
#
#   defendersInTheBox
# 0                 7
# 1                 5
# 2                 7
# 3                 5
# 5                 4
#
# [5 rows x 23 columns]

# %%
plays_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13960 entries, 0 to 13959
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   position                13960 non-null  string
#  1   gameId                  13960 non-null  int64
#  2   playId                  12763 non-null  float64
#  3   ballCarrierId           12763 non-null  string
#  4   ballCarrierDisplayName  12763 non-null  string
#  5   playDescription         12763 non-null  string
#  6   quarter                 12763 non-null  float64
#  7   down                    12763 non-null  float64
#  8   yardsToGo               12763 non-null  float64
#  9   possessionTeam          12763 non-null  string
#  10  defensiveTeam           12763 non-null  string
#  11  yardlineSide            12594 non-null  string
#  12  yardlineNumber          12763 non-null  float64
#  13  gameClock               12763 non-null  datetime64[ns]
#  14  preSnapHomeScore        12763 non-null  float64
#  15  preSnapVisitorScore     12763 non-null  float64
#  16  passResult              6207 non-null   string
#  17  passLength              5688 non-null   float64
#  18  playResult              12763 non-null  float64
#  19  playNullifiedByPenalty  12763 non-null  string
#  20  absoluteYardlineNumber  12763 non-null  float64
#  21  offenseFormation        12759 non-null  string
#  22  defendersInTheBox       13960 non-null  int64
# dtypes: datetime64[ns](1), float64(10), int64(2), string(10)
# memory usage: 2.6 MB

# %%
plays_df_clean = plays_df_clean[[ 'gameId', 'playId', 'ballCarrierId', 'ballCarrierDisplayName', 'position','playDescription', 'quarter', 'down', 'yardsToGo', 'possessionTeam', 'defensiveTeam', 'yardlineSide', 'yardlineNumber', 'gameClock', 'preSnapHomeScore', 'preSnapVisitorScore', 'passResult', 'passLength', 'playResult', 'playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation', 'defendersInTheBox']]

# %%
# Filter rows based on column: 'down'
plays_3rd_down_df = plays_df_clean[plays_df_clean['down'] == 3]
plays_3rd_down_df.head()
# Out:
#        gameId  playId ballCarrierId ballCarrierDisplayName position  \
# 1  2022092512  2687.0       25511.0              Tom Brady       QB
# 2  2022101607  3652.0       25511.0              Tom Brady       QB
# 3  2022102700  3083.0       25511.0              Tom Brady       QB
# 5  2022110603  3064.0       29851.0          Aaron Rodgers       QB
# 7  2022091812  2969.0       29851.0          Aaron Rodgers       QB
#
#                                      playDescription  quarter  down  \
# 1  (1:08) (Shotgun) T.Brady scrambles up the midd...      3.0   3.0
# 2  (7:07) T.Brady up the middle to PIT 29 for no ...      4.0   3.0
# 3  (13:22) (Shotgun) T.Brady scrambles left end t...      4.0   3.0
# 5  (12:24) (Shotgun) A.Rodgers scrambles up the m...      4.0   3.0
# 7  (6:38) (Shotgun) A.Rodgers right end to GB 13 ...      4.0   3.0
#
#    yardsToGo possessionTeam  ...           gameClock preSnapHomeScore  \
# 1        3.0             TB  ... 2024-03-17 01:08:00              6.0
# 2        1.0             TB  ... 2024-03-17 07:07:00             20.0
# 3       10.0             TB  ... 2024-03-17 13:22:00             10.0
# 5       17.0             GB  ... 2024-03-17 12:24:00             15.0
# 7        2.0             GB  ... 2024-03-17 06:38:00             24.0
#
#    preSnapVisitorScore passResult  passLength  playResult  \
# 1                 14.0          R         NaN       -10.0
# 2                 12.0       <NA>         NaN         0.0
# 3                 17.0          R         NaN         1.0
# 5                  6.0          R         NaN        18.0
# 7                 10.0       <NA>         NaN         4.0
#
#   playNullifiedByPenalty  absoluteYardlineNumber  offenseFormation  \
# 1                      Y                    80.0             EMPTY
# 2                      N                    81.0        SINGLEBACK
# 3                      N                    23.0           SHOTGUN
# 5                      N                    46.0           SHOTGUN
# 7                      N                   101.0           SHOTGUN
#
#   defendersInTheBox
# 1                 5
# 2                 7
# 3                 5
# 5                 4
# 7                 6
#
# [5 rows x 23 columns]

# %%
plays_4th_down_df = plays_df_clean[plays_df_clean['down'] == 4]
plays_4th_down_df.head()
# Out:
#          gameId  playId ballCarrierId ballCarrierDisplayName position  \
# 14   2022092502  3467.0       33084.0              Matt Ryan       QB
# 71   2022102700  4249.0       37079.0            Julio Jones       WR
# 205  2022103000  1533.0       38605.0         Russell Wilson       QB
# 209  2022103000  4058.0       38605.0         Russell Wilson       QB
# 250  2022102304  4412.0       38696.0           Marvin Jones       WR
#
#                                        playDescription  quarter  down  \
# 14   (6:39) M.Ryan up the middle to IND 35 for 2 ya...      4.0   4.0
# 71   (:53) (Shotgun) T.Brady pass short right to J....      4.0   4.0
# 205  (5:23) R.Wilson up the middle to JAX 34 for 2 ...      2.0   4.0
# 209  (:36) R.Wilson right guard to JAX 25 for 1 yar...      4.0   4.0
# 250  (:22) (Shotgun) T.Lawrence pass deep middle to...      4.0   4.0
#
#      yardsToGo possessionTeam  ...           gameClock preSnapHomeScore  \
# 14         1.0            IND  ... 2024-03-17 06:39:00             13.0
# 71         8.0             TB  ... 2024-03-17 00:53:00             16.0
# 205        1.0            DEN  ... 2024-03-17 05:23:00             10.0
# 209        1.0            DEN  ... 2024-03-17 00:36:00             17.0
# 250       15.0            JAX  ... 2024-03-17 00:22:00             17.0
#
#      preSnapVisitorScore passResult  passLength  playResult  \
# 14                  17.0       <NA>         NaN         2.0
# 71                  27.0          C         3.0         8.0
# 205                  0.0       <NA>         NaN         2.0
# 209                 21.0       <NA>         NaN         1.0
# 250                 23.0          C        22.0        43.0
#
#     playNullifiedByPenalty  absoluteYardlineNumber  offenseFormation  \
# 14                       N                    43.0        SINGLEBACK
# 71                       N                    18.0           SHOTGUN
# 205                      N                    46.0        SINGLEBACK
# 209                      N                    84.0            I_FORM
# 250                      N                    50.0             EMPTY
#
#     defendersInTheBox
# 14                  8
# 71                  5
# 205                 7
# 209                10
# 250                 4
#
# [5 rows x 23 columns]

# %% [markdown]
# merged_df = pd.merge(matchups_df, tracking_test_df, how='left', left_on='gameId', right_on='gameId')
# merged_df.head()
